# %% [markdown]
# # Feature Exploration
#
# Use this notebook to inspect the feature table produced by the current pipeline and validate whether the model inputs look sensible.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

ROOT
# Out:
# WindowsPath('c:/Users/abhui/OneDrive/Documents/GitHub/ai-investment-lab')

# %%
import pandas as pd

from ai_models.feature_builder import build_feature_table

result = build_feature_table(
    fundamentals_path=str(ROOT / "data" / "fundamentals_cache.parquet"),
    prices_path=str(ROOT / "data" / "prices_cache.parquet"),
    treasury_path=str(ROOT / "data" / "treasury_yields_cache.parquet"),
    benchmark_ticker="SPY",
)

features = result.features.reset_index()
features.head()
# Out:
#   Ticker  Momentum_12M  Volatility_63D  Drawdown_252D  Return_21D  \
# 0      A     -0.081941        0.255104      -0.290719   -0.119044
# 1   AAPL      0.157177        0.235290      -0.132667   -0.048315
# 2   ABBV     -0.001417        0.269842      -0.148006   -0.085937
# 3   ABNB      0.020000        0.331808      -0.095948    0.021540
# 4    ABT     -0.156814        0.274151      -0.225497   -0.059988
#
#    Revenue_Growth_YoY_Pct  EBITDA_Margin       ROE  FreeCashFlow_Margin  \
# 0                6.728111        0.27898   0.19946                  NaN
# 1                6.425512        0.35100   1.52021                  NaN
# 2                8.566763        0.47832  62.25000                  NaN
# 3               10.259413        0.21028   0.30233                  NaN
# 4                5.668653        0.27145   0.12961                  NaN
#
#    Benchmark_Volatility  Benchmark_Trend  YC_10Y_2Y  YC_10Y_3M  YC_Inversion  \
# ...

# %%
result.warnings
# Out:
# []

# %%
features.describe(include="all").transpose()
# Out:
#                         count unique  top freq      mean        std  \
# Ticker                    521    521    A    1       NaN        NaN
# Momentum_12M            520.0    NaN  NaN  NaN  0.164216   0.730676
# Volatility_63D          521.0    NaN  NaN  NaN  0.338904   0.138491
# Drawdown_252D           521.0    NaN  NaN  NaN -0.196599   0.134886
# Return_21D              521.0    NaN  NaN  NaN -0.060434   0.089886
# Revenue_Growth_YoY_Pct  509.0    NaN  NaN  NaN  9.344695  15.643513
# EBITDA_Margin           516.0    NaN  NaN  NaN  0.254725   0.209207
# ROE                     487.0    NaN  NaN  NaN  0.534507   4.319011
# FreeCashFlow_Margin       0.0    NaN  NaN  NaN       NaN        NaN
# Benchmark_Volatility    521.0    NaN  NaN  NaN  0.121457        0.0
# Benchmark_Trend         521.0    NaN  NaN  NaN   0.15703        0.0
# YC_10Y_2Y               521.0    NaN  NaN  NaN      0.46        0.0
# YC_10Y_3M               521.0    NaN  NaN  NaN      0.52        0.0
# ...

# %%
missing = features.isna().sum().sort_values(ascending=False)
missing[missing > 0]
# Out:
# FreeCashFlow_Margin       521
# ROE                        34
# Revenue_Growth_YoY_Pct     12
# EBITDA_Margin               5
# Momentum_12M                1
# dtype: int64
